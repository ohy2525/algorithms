# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/10814

# %%
n = int(input())
array = []

for i in range(n):
    x, y = input().split()
    x = int(x)
    array.append([x, i, y])
    
array.sort()
for x, i, y in array:
    print(x, y)
# Out:
# 3
# 21 Junkyu
# 21 Dohyun
# 20 Sunyoung
# 20 Sunyoung
# 21 Junkyu
# 21 Dohyun
