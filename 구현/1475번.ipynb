# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/1475

# %%
n = input()
num = [0] * 10
for i in n:
    if i == '9':
        num[6] = num[6] + 1
    else:
        num[int(i)] = num[int(i)] + 1

if num[6] % 2 == 0:
    num[6] = num[6] // 2
else:
    num[6] = num[6] // 2 + 1

print(max(num))
# Out:
# 999998
# 3
