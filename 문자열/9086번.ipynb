# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/9086

# %%
n = int(input())
for _ in range(n):
    tmp = input()
    ans = tmp[0] + tmp[-1]
    print(ans)
# Out:
# 1
# o
# oo
