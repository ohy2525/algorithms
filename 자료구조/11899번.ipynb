# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/11899

# %%
w = input()
ans = 0
l = 0
for i in w:
    if i == '(': 
        l += 1
    else:
        if l < 1:
            ans += 1
            l = 0
        else: l -= 1
            
print(ans + l)
# Out:
# )))()
# 3
