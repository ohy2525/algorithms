# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/1912

# %%
n = int(input())
num = list(map(int, input().split()))

ans = [num[0]]

for i in range(n - 1):
    ans.append(max(ans[i] + num[i + 1], num[i + 1]))
    
print(max(ans))
# Out:
# 10
# 10 -4 3 1 5 6 -35 12 21 -1
# 33
