# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/2193

# %%
n = int(input())
dp = [0, 1, 1]
for i in range(3, 91):
    dp.append(dp[i-1] + dp[i-2])
print(dp[n])
# Out:
# 6
# 8

# %%
n = int(input())
dp = [0] * 91
dp[1] = 1
dp[2] = 1
for i in range(3, 91):
    dp[i] = dp[i-1] + dp[i-2]
print(dp[n])
# Out:
# 6
# 8
