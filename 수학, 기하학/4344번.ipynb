# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/4344

# %%
n = int(input())
for _ in range(n):
    grade = list(map(int, input().split()))
    ans = sum([x > sum(grade[1:])/len(grade[1:]) for x in grade[1:]]) / len(grade[1:])*100
    print(f'{ans:.3f}%')
# Out:
# 5
# 5 50 50 70 80 100
# 40.000%
# 7 100 95 90 80 70 60 50
# 57.143%
# 3 70 90 80
# 33.333%
# 3 70 90 81
# 66.667%
# 9 100 99 98 97 96 95 94 93 91
# 55.556%
