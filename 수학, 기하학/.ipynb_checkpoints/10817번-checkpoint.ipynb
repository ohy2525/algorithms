# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/10817

# %%
ans = list(map(int, input().split()))

ans.sort()
print(ans[1])
# Out:
# 20 30 10
# 20
