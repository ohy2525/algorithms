# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/18870

# %%
n = int(input())
array = list(map(int, input().split()))

array_sort = sorted(list(set(array)))

dic = {array_sort[i] : i for i in range(len(array_sort))}

for i in array:
    print(dic[i], end = ' ')
# Out:
# 5
# 2 4 -10 4 -9
# 2 3 0 3 1

# %%
dic
# Out:
# {-10: 0, -9: 1, 2: 2, 4: 3}

# %%
array = set(array)
array = list(array)
array
# Out:
# [2, 4, -10, -9]

# %%
array.sort()
array
# Out:
# [-10, -9, 2, 4]

# %%
for i in range(len(array)):
    if array[i] == 2 :
        print(i)
# Out:
# 2
