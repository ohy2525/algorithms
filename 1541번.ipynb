# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/1541

# %%
num = input().split('-')
ans = 0
for i in num[0].split('+'):
    ans += int(i)
for i in num[1:]:
    for j in i.split('+'):
        ans -= int(j)
print(ans)
# Out:
# 55-50+40
# -35
