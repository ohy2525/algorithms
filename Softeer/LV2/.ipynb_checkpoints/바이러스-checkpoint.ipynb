# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://softeer.ai/practice/6284

# %%
import sys
input = sys.stdin.readline

k, p, n = map(int, input().split())

print(pow(p, n, 1000000007) * k % 1000000007)
