# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/16113

# %%
n = int(input())
signal = input()
# Out:
# 40
# ###..#..#.#..#..###..#..#.#..#..###..#..

# %%
signal[:8]
# Out:
# '###..#..'
