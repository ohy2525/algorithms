# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/1748

# %%
n = int(input())

if len(str(n)) == 1:
    print(n)

else :
    a = len(str(n))
    b = n - 10 ** (a - 1) + 1
    ans = 0
    for i in range(a - 1):
        ans += 9*(i+1)*10**i
        
    print(ans + a * b)
# Out:
# 120
# 252
