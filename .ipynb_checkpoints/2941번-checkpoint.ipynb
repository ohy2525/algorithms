# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/2941

# %%
import re
s = input()
cro = ['c=', 'c-', 'dz=', 'd-', 'lj', 'nj', 's=', 'z=']
for i in cro:
    s = re.sub(i, 'a', s)
print(len(s))
# Out:
# c=c=
# 2
