# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/8958

# %%
n = int(input())
for _ in range(n):
    ox = input()
    result = 0
    score = 1
    for i in range(len(ox)):
        if ox[i] == 'O':
            result += score
            score +=1
        else :
            score = 1
    print(result)
# Out:
# 5
# ooxxoxxooo
# 10
# ooxxooxxoo
# 9
# oxoxoxoxoxoxox
# 7
# oooooooooo
# 55
# ooooxooooxoooox
# 30
