# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/2847

# %%
n = int(input())
arr = []
for _ in range(n):
    arr.append(int(input()))
    
ans = 0

while len(arr) > 1:
    score = arr.pop()
    if arr[-1] >= score:
        ans += arr[-1] - score + 1
        arr[-1] = score - 1
        
print(ans)
# Out:
# 3
# 5
# 5
# 5
# 3
