# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/2875

# %%
n, m, k = map(int, input().split())
answer = 0
while n >= 2 and m >= 1:
    if n + m - 3 < k:
        break
    n -= 2
    m -= 1
    answer += 1
    
print(answer)
# Out:
# 6 10 3
# 3
