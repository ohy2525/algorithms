# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.acmicpc.net/problem/1049

# %%
n, m = map(int, input().split())
six = []
one = []
for _ in range(m):
    a, b = map(int, input().split())
    six.append(a)
    one.append(b)

ans = min(min(six) * (n // 6 + 1), min(six) * (n // 6) + min(one) * (n % 6), min(one) * n)

print(ans)
# Out:
# 6 1
# 7 1
# 6
